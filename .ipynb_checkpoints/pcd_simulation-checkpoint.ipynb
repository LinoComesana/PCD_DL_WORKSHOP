# %% [markdown]
# # 2. Simulating point clouds with python
#
# Once all the dependencies are installed, we can start to simulate point clouds with python. In this course we will consider a very simple scenario of a forest made by **trees** and **ground** points. Just that. And the purpose of this generation is to train a Deep Learning (DL) model with different synthetic point clouds generated by our program in order to perform a semantic classification of every single point in a forest point cloud.
#
# Before getting started, it is neccessary to give a little hint about **what is semantic segmentation**. In both images or point clouds, every single unit of information (pixel and point, respectively) can be classified depending on which semantic group it belongs to. In other words, **one can classify a set of pixels in an image as a semantic group of information**. For example, in the following figure we have a picture of a room with different furniture elements, and if we consider only the semantic information of the classes _"chair"_ and _"table"_ we can differentiate clearly the pixels that belong to each class.
#
# ![alternative text](images/semantic_vs_instance_segmentation.png)
#
# If we want to go even further, it can be possible to separate individually each element or **instance** within the semantic information, as shown at the right part of the previous image. However, in this course we will limit ourselves to perform semantic classification only.
#
# Of ourse, this technique can be applied to other type of data, as we will do with LiDAR point clouds. Since we will consider only **trees** and **ground** points, there will be only 2 semantic classes, and every point that we will create need to belong to one of these classes.
#
# The methodology followed in the next steps will be sorted in 3 parts: **generation of the Digital Terrain Model (DTM)**, **generation of modified tree segments** and, finally, **merge of the semantic information in a single point cloud**.

# %% [markdown]
# ## 2.1. Generation of the DTM
#
# The Digital Terrain Model (DTM) will be the base for our generation, since it will be made of all points classified as **ground** and all trees must be placed over them.
#
# First, we will define a square-grid of 1 million points at a height of _z = 0_ m with 100 m per edge:

# %%
import numpy as np
import open3d as o3d

ruta_proyecto_workshop = os.getcwd()+'/PCD_DL_WORKSHOP'

print(os.listdir())

eje_x = np.arange(0,100,0.1)
eje_y = np.arange(0,100,0.1)

SUPERFICIE = {}
mesh_x, mesh_y = np.meshgrid(eje_x,eje_y)

xyz = np.zeros((np.size(mesh_x), 3))
xyz[:, 0] = np.reshape(mesh_x, -1)
xyz[:, 1] = np.reshape(mesh_y, -1)


nube_plano = o3d.geometry.PointCloud()
nube_plano.points = o3d.utility.Vector3dVector(xyz)

# VISUALIZATION TEST ----------------------------------------------------------
o3d.visualization.draw_geometries([nube_plano])
#------------------------------------------------------------------------------
# Out:
# ['arboles.npy', 'DTM.npy']

# %% [markdown]
# The result should be something like this:
#
# ![alternative text](images/square_grid.png)
#
# Now, we select randonmly some points in the grid and we will change their height:

# %%
N_picos = np.random.randint(10,50)
for q in range(N_picos):
    indices_puntos = np.arange(0,len(xyz),1)
    indice_punto_central_pico = np.random.choice(indices_puntos,size=1)
    punto_central = xyz[indice_punto_central_pico]
    nube_punto_central = o3d.geometry.PointCloud()
    nube_punto_central.points = o3d.utility.Vector3dVector(np.vstack((punto_central,
                                                                      punto_central)))
    buffer = np.random.randint(10,20)
    # Cojo todos los punntos dentro de ese buffer respecto al punto central:
    distancias = np.array(nube_plano.compute_point_cloud_distance(nube_punto_central))
    indices_dentro_buffer = np.where(distancias <= buffer)[0]

    # indices_cambios_altura = indices_puntos
    xyz[indices_dentro_buffer,2] = np.random.uniform(buffer/2.,buffer,size=len(indices_dentro_buffer)).T


pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(xyz)

# VISUALIZATION TEST ----------------------------------------------------------
o3d.visualization.draw_geometries([pcd])
#------------------------------------------------------------------------------

# %% [markdown]
# The result should be something similar to this:
#
# ![alternative text](images/random_heights.png)

# %% [markdown]
# Now we will create a digital surface that "adapts" to this points. It will not adapt perfectly all of those points but that is not a problem since what we are looking for is to a smooth and randomly generated surface to simulate our DTM:

# %%
# We define some useful functions:
import itertools

Numero_puntos_superficie = 1e6

def exponential_cov(x, y, params):
    return params[0] * np.exp( -0.5 * params[1] * np.subtract.outer(x, y)**2)

def conditional(x_new, x, y, params):
    B = exponential_cov(x_new, x, params)
    C = exponential_cov(x, x, params)
    A = exponential_cov(x_new, x_new, params)
    mu = np.linalg.inv(C).dot(B.T).T.dot(y)
    sigma = A - B.dot(np.linalg.inv(C).dot(B.T))
    return(mu.squeeze(), sigma.squeeze())

ordr = 4  # Orden del polinomio al que quiero ajustar en cada "frame"

def matriz_minimos_cuadrados(x, y, order=ordr):
    """ generate Matrix use with lstsq """
    # Genero una matriz con los valores obtenidos por mínimos cuadrados
    ncolumnas = (order + 1)**2
    G = np.zeros((x.size, ncolumnas))
    ij = itertools.product(range(order+1), range(order+1))
    for k, (i, j) in enumerate(ij):
        G[:, k] = x**i * y**j
    return G


puntos = np.copy(xyz)

x, y, z = puntos.T # Hago la traspuesta
x, y = x - x[0], y - y[0]  # Para mejorar la eficacia

# Creamos la matriz que contiene las regresiones por punto:
G = matriz_minimos_cuadrados(x, y, ordr)
# Solve for np.dot(G, m) = z:
# Quiero saber qué valores de m hacen que G·m = z (es decir, np.dot(G,m)=z)
m = np.linalg.lstsq(G, z)[0]


# Evaluamos en una nueva grid el ajuste que acabamos de hacer...
nx, ny = int(np.sqrt(Numero_puntos_superficie)), int(np.sqrt(Numero_puntos_superficie))
xx, yy = np.meshgrid(np.linspace(x.min(), x.max(), nx),
                      np.linspace(y.min(), y.max(), ny))


GG = matriz_minimos_cuadrados(xx.ravel(), yy.ravel(), ordr)
zz = np.reshape(np.dot(GG, m), xx.shape)

# Convierto la superficie del fit a una nube de puntos:
superficie_reconstruida = np.zeros((np.size(xx), 3))
superficie_reconstruida[:, 0] = np.reshape(xx, -1)
superficie_reconstruida[:, 1] = np.reshape(yy, -1)
superficie_reconstruida[:, 2] = np.reshape(zz, -1)

pcd2 = o3d.geometry.PointCloud()
pcd2.points = o3d.utility.Vector3dVector(superficie_reconstruida)

# VISUALIZATION TEST ----------------------------------------------------------
o3d.visualization.draw_geometries([pcd2])
#------------------------------------------------------------------------------
# Out:
# <ipython-input-86-d927c81a23a0>:39: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m = np.linalg.lstsq(G, z)[0]

# %% [markdown]
# ![alternative text](images/dtm_simple.png)

# %% [markdown]
# We will add some gaussian noise to the DTM since it looks _"too artificial"_. Also, we will apply a brown-like color to differentiate it from the trees in further steps:

# %%
# Ahora le añadimos algo de ruido gaussiano a cada punto para hacerlo más real:
ruido_x = np.random.normal(0,eje_x[2]-eje_x[1],len(superficie_reconstruida))
ruido_y = np.random.normal(0,eje_y[2]-eje_y[1],len(superficie_reconstruida))
# ruido_z = np.random.normal(0,0.2,len(superficie_reconstruida))

superficie_reconstruida[:, 0] = np.reshape(superficie_reconstruida.take(0,1) + ruido_x, -1)
superficie_reconstruida[:, 1] = np.reshape(superficie_reconstruida.take(1,1) + ruido_y, -1)
# superficie_reconstruida[:, 2] = np.reshape(superficie_reconstruida.take(2,1) + ruido_z, -1)


pcd_DTM = o3d.geometry.PointCloud()
pcd_DTM.points = o3d.utility.Vector3dVector(superficie_reconstruida)

lista_colores_suelo = [np.array([51/255,51/255,0/255]),
                 np.array([102/255,102/255,0/255]),
                 np.array([153/255,153/255,0/255]),
                 np.array([204/255,204/255,0/255]),
                 np.array([255/255,255/255,0/255]),
                 np.array([102/255,51/255,0/255]),
                 np.array([153/255,76/255,0/255]),
                 np.array([204/255,102/255,0/255])]

colores_suelo = np.zeros((len(superficie_reconstruida),3))
for e in range(len(colores_suelo)):
    colores_suelo[e] = lista_colores_suelo[np.random.choice(len(lista_colores_suelo))]

pcd_DTM.colors = o3d.utility.Vector3dVector(colores_suelo)


# VISUALIZATION TEST ----------------------------------------------------------
o3d.visualization.draw_geometries([pcd_DTM])
#------------------------------------------------------------------------------

# %% [markdown]
# Finally, the synthetic DTM should be something similar to this:
#
# ![alternative text](images/synthetic_DTM.png)

# %% [markdown]
# ## 2.2. Generation of modified tree segments
#
# We will read some point clouds that are actually saved in the folder /data/trees_pcd and manipulate them in order to generate slighlty modified copies of each tree:

# %%
from LECTURAS_segmentacion_cilindrica import lectura_segmentaciones
import os
import math

print(os.listdir())

os.chdir(ruta_proyecto_workshop+'/data/trees_pcd')

ruta_actual = os.getcwd()
print(ruta_actual)

SEGMENTOS = lectura_segmentaciones(ruta_actual)
os.chdir(ruta_actual)

numero_de_transformaciones_por_arbol = 3

def rotar_punto(origen, punto, angulo):

    # Ángulo en radianes

    ox, oy = origen
    px, py = punto[0],punto[1]

    qx = ox + math.cos(angulo) * (px - ox) - math.sin(angulo) * (py - oy)
    qy = oy + math.sin(angulo) * (px - ox) + math.cos(angulo) * (py - oy)
    return np.array([qx, qy,punto[2]])

SEGMENTOS_ARTIFICIALES = {}


contador_arboles = 0
for j in range(numero_de_transformaciones_por_arbol):
    for i in range(len(SEGMENTOS)):

        segmento = SEGMENTOS[i]

        # Todos los árboles que vayamos a crear se verán sometidos a, como mínimo, una
        # rotación en el plano XY. Para ello calculamos primero su eje de simetría:


        cgx = (1/len(segmento.points))*(np.sum(np.array(segmento.points).take(0,1)))
        cgy = (1/len(segmento.points))*(np.sum(np.array(segmento.points).take(1,1)))
        #cgz = (1/len(segmento.points))*(np.sum(np.array(segmento.points).take(2,1)))

        centro_de_masas = [cgx,cgy]

        puntos_rotados = []

        angulo = np.random.random() # En radianes lo cogemos

        for punto in segmento.points:
            puntos_rotados.append(rotar_punto(centro_de_masas, punto, angulo))

        puntos_rotados = np.array(puntos_rotados)

        segmento_rotado = o3d.geometry.PointCloud()
        segmento_rotado.points = o3d.utility.Vector3dVector(puntos_rotados)


        # Ahora le vamos a meter algo de ruido (pero sólo a los puntos que
        # estén por encima de una determinada altura).

        dispersion = np.mean(segmento_rotado.compute_point_cloud_distance(segmento))


        altura_media = np.mean(puntos_rotados[:,2])

        indices = np.where(puntos_rotados[:,2]>altura_media)[0]

        ruido_x = np.random.normal(0,dispersion,len(indices))
        ruido_y = np.random.normal(0,dispersion,len(indices))
        ruido_z = np.random.normal(0,0.5,len(indices))

        # print(indices)
        # print()
        # print(puntos_rotados)

        puntos_rotados[indices, 0] = np.reshape(puntos_rotados[indices, 0] + ruido_x, -1)
        puntos_rotados[indices, 1] = np.reshape(puntos_rotados[indices, 1] + ruido_y, -1)
        puntos_rotados[indices, 2] = np.reshape(puntos_rotados[indices, 2] + ruido_z, -1)


        # Volvemos a definir el nuevo árbol:
        arbol_artificial = o3d.geometry.PointCloud()
        arbol_artificial.points = o3d.utility.Vector3dVector(puntos_rotados)

        # Lo pintamos con un color:
        lista_colores_arbol = [np.array([0/255,51/255,0/255]),
                         np.array([0/255,102/255,0/255]),
                         np.array([0/255,153/255,0/255]),
                         np.array([0/255,204/255,0/255]),
                         np.array([0/255,255/255,0/255]),
                         np.array([51/255,255/255,51/255]),
                         np.array([102/255,255/255,102/255])]

        colores_arbol = np.zeros((len(puntos_rotados),3))
        for e in range(len(colores_arbol)):
            colores_arbol[e] = lista_colores_arbol[np.random.choice(len(lista_colores_arbol))]

        arbol_artificial.colors = o3d.utility.Vector3dVector(colores_arbol)




        # El False se lo pongo para designar que no ha sido seleccionado to-
        # davía:
        SEGMENTOS_ARTIFICIALES[contador_arboles] = [arbol_artificial,False]
        contador_arboles += 1
# Out:
# ['PCD_DL_WORKSHOP']
# /home/lino/Documentos/PCD_DL_WORKSHOP/PCD_DL_WORKSHOP/data/trees_pcd

# %%
SEGMENTOS_ARTIFICIALES
# Out:
# {0: [PointCloud with 489 points., False],
#  1: [PointCloud with 7022 points., False],
#  2: [PointCloud with 2307 points., False],
#  3: [PointCloud with 7426 points., False],
#  4: [PointCloud with 4860 points., False],
#  5: [PointCloud with 1657 points., False],
#  6: [PointCloud with 13 points., False],
#  7: [PointCloud with 2601 points., False],
#  8: [PointCloud with 8752 points., False],
#  9: [PointCloud with 3705 points., False],
#  10: [PointCloud with 5681 points., False],
#  11: [PointCloud with 2649 points., False],
#  12: [PointCloud with 12766 points., False],
#  13: [PointCloud with 924 points., False],
#  14: [PointCloud with 5520 points., False],
#  15: [PointCloud with 3138 points., False],
#  16: [PointCloud with 3906 points., False],
#  17: [PointCloud with 3869 points., False],
#  18: [PointCloud with 4256 points., False],
#  19: [PointCloud with 16120 points., False],
#  20: [PointCloud with 12 points., False],
#  21: [PointCloud with 10517 points., False],
#  22: [PointCloud with 1802 points., False],
#  23: [PointCloud with 1005 points., False],
#  24: [PointCloud with 1371 points., False],
#  25: [PointCloud with 4127 points., False],
#  26: [PointCloud with 2955 points., False],
#  27: [PointCloud with 7178 points., False],
#  28: [PointCloud with 8054 points., False],
#  29: [PointCloud with 7829 points., False],
#  30: [PointCloud with 1413 points., False],
#  31: [PointCloud with 1403 points., False],
#  32: [PointCloud with 3594 points., False],
#  33: [PointCloud with 5823 points., False],
#  34: [PointCloud with 1906 points., False],
#  35: [PointCloud with 10156 points., False],
#  36: [PointCloud with 6929 points., False],
#  37: [PointCloud with 1420 points., False],
#  38: [PointCloud with 1303 points., False],
#  39: [PointCloud with 972 points., False],
#  40: [PointCloud with 938 points., False],
#  41: [PointCloud with 1310 points., False],
#  42: [PointCloud with 9812 points., False],
#  43: [PointCloud with 485 points., False],
#  44: [PointCloud with 8017 points., False],
#  45: [PointCloud with 782 points., False],
#  46: [PointCloud with 956 points., False],
#  47: [PointCloud with 1842 points., False],
#  48: [PointCloud with 2550 points., False],
#  49: [PointCloud with 7776 points., False],
#  50: [PointCloud with 5982 points., False],
#  51: [PointCloud with 19952 points., False],
#  52: [PointCloud with 3048 points., False],
#  53: [PointCloud with 3355 points., False],
#  54: [PointCloud with 5022 points., False],
#  55: [PointCloud with 1644 points., False],
#  56: [PointCloud with 19188 points., False],
#  57: [PointCloud with 10412 points., False],
#  58: [PointCloud with 6454 points., False],
#  59: [PointCloud with 701 points., False],
#  60: [PointCloud with 1463 points., False],
#  61: [PointCloud with 4977 points., False],
#  62: [PointCloud with 6123 points., False],
#  63: [PointCloud with 282 points., False],
#  64: [PointCloud with 465 points., False],
#  65: [PointCloud with 4569 points., False],
#  66: [PointCloud with 5951 points., False],
#  67: [PointCloud with 734 points., False],
#  68: [PointCloud with 12168 points., False],
#  69: [PointCloud with 5317 points., False],
#  70: [PointCloud with 6092 points., False],
#  71: [PointCloud with 3752 points., False],
#  72: [PointCloud with 3807 points., False],
#  73: [PointCloud with 3601 points., False],
#  74: [PointCloud with 10802 points., False],
#  75: [PointCloud with 8801 points., False],
#  76: [PointCloud with 8070 points., False],
#  77: [PointCloud with 9084 points., False],
#  78: [PointCloud with 22505 points., False],
#  79: [PointCloud with 8879 points., False],
#  80: [PointCloud with 681 points., False],
#  81: [PointCloud with 8727 points., False],
#  82: [PointCloud with 15739 points., False],
#  83: [PointCloud with 7934 points., False],
#  84: [PointCloud with 3652 points., False],
#  85: [PointCloud with 11245 points., False],
#  86: [PointCloud with 2102 points., False],
#  87: [PointCloud with 9652 points., False],
#  88: [PointCloud with 9516 points., False],
#  89: [PointCloud with 2814 points., False],
#  90: [PointCloud with 9979 points., False],
#  91: [PointCloud with 8262 points., False],
#  92: [PointCloud with 14150 points., False],
#  93: [PointCloud with 2317 points., False],
#  94: [PointCloud with 695 points., False],
#  95: [PointCloud with 1506 points., False],
#  96: [PointCloud with 4330 points., False],
#  97: [PointCloud with 9301 points., False],
#  98: [PointCloud with 2675 points., False],
#  99: [PointCloud with 983 points., False],
#  100: [PointCloud with 4966 points., False],
#  101: [PointCloud with 778 points., False],
#  102: [PointCloud with 402 points., False],
#  103: [PointCloud with 5192 points., False],
#  104: [PointCloud with 6897 points., False],
#  105: [PointCloud with 574 points., False],
#  106: [PointCloud with 652 points., False],
#  107: [PointCloud with 589 points., False],
#  108: [PointCloud with 5943 points., False],
#  109: [PointCloud with 3419 points., False],
#  110: [PointCloud with 6796 points., False],
#  111: [PointCloud with 1980 points., False],
#  112: [PointCloud with 69 points., False],
#  113: [PointCloud with 2179 points., False],
#  114: [PointCloud with 6983 points., False],
#  115: [PointCloud with 11117 points., False],
#  116: [PointCloud with 5858 points., False],
#  117: [PointCloud with 926 points., False],
#  118: [PointCloud with 13818 points., False],
#  119: [PointCloud with 489 points., False],
#  120: [PointCloud with 7022 points., False],
#  121: [PointCloud with 2307 points., False],
#  122: [PointCloud with 7426 points., False],
#  123: [PointCloud with 4860 points., False],
#  124: [PointCloud with 1657 points., False],
#  125: [PointCloud with 13 points., False],
#  126: [PointCloud with 2601 points., False],
#  127: [PointCloud with 8752 points., False],
#  128: [PointCloud with 3705 points., False],
#  129: [PointCloud with 5681 points., False],
#  130: [PointCloud with 2649 points., False],
#  131: [PointCloud with 12766 points., False],
#  132: [PointCloud with 924 points., False],
#  133: [PointCloud with 5520 points., False],
#  134: [PointCloud with 3138 points., False],
#  135: [PointCloud with 3906 points., False],
#  136: [PointCloud with 3869 points., False],
#  137: [PointCloud with 4256 points., False],
#  138: [PointCloud with 16120 points., False],
#  139: [PointCloud with 12 points., False],
#  140: [PointCloud with 10517 points., False],
#  141: [PointCloud with 1802 points., False],
#  142: [PointCloud with 1005 points., False],
#  143: [PointCloud with 1371 points., False],
#  144: [PointCloud with 4127 points., False],
#  145: [PointCloud with 2955 points., False],
#  146: [PointCloud with 7178 points., False],
#  147: [PointCloud with 8054 points., False],
#  148: [PointCloud with 7829 points., False],
#  149: [PointCloud with 1413 points., False],
#  150: [PointCloud with 1403 points., False],
#  151: [PointCloud with 3594 points., False],
#  152: [PointCloud with 5823 points., False],
#  153: [PointCloud with 1906 points., False],
#  154: [PointCloud with 10156 points., False],
#  155: [PointCloud with 6929 points., False],
#  156: [PointCloud with 1420 points., False],
#  157: [PointCloud with 1303 points., False],
#  158: [PointCloud with 972 points., False],
#  159: [PointCloud with 938 points., False],
#  160: [PointCloud with 1310 points., False],
#  161: [PointCloud with 9812 points., False],
#  162: [PointCloud with 485 points., False],
#  163: [PointCloud with 8017 points., False],
#  164: [PointCloud with 782 points., False],
#  165: [PointCloud with 956 points., False],
#  166: [PointCloud with 1842 points., False],
#  167: [PointCloud with 2550 points., False],
#  168: [PointCloud with 7776 points., False],
#  169: [PointCloud with 5982 points., False],
#  170: [PointCloud with 19952 points., False],
#  171: [PointCloud with 3048 points., False],
#  172: [PointCloud with 3355 points., False],
#  173: [PointCloud with 5022 points., False],
#  174: [PointCloud with 1644 points., False],
#  175: [PointCloud with 19188 points., False],
#  176: [PointCloud with 10412 points., False],
#  177: [PointCloud with 6454 points., False],
#  178: [PointCloud with 701 points., False],
#  179: [PointCloud with 1463 points., False],
#  180: [PointCloud with 4977 points., False],
#  181: [PointCloud with 6123 points., False],
#  182: [PointCloud with 282 points., False],
#  183: [PointCloud with 465 points., False],
#  184: [PointCloud with 4569 points., False],
#  185: [PointCloud with 5951 points., False],
#  186: [PointCloud with 734 points., False],
#  187: [PointCloud with 12168 points., False],
#  188: [PointCloud with 5317 points., False],
#  189: [PointCloud with 6092 points., False],
#  190: [PointCloud with 3752 points., False],
#  191: [PointCloud with 3807 points., False],
#  192: [PointCloud with 3601 points., False],
#  193: [PointCloud with 10802 points., False],
#  194: [PointCloud with 8801 points., False],
#  195: [PointCloud with 8070 points., False],
#  196: [PointCloud with 9084 points., False],
#  197: [PointCloud with 22505 points., False],
#  198: [PointCloud with 8879 points., False],
#  199: [PointCloud with 681 points., False],
#  200: [PointCloud with 8727 points., False],
#  201: [PointCloud with 15739 points., False],
#  202: [PointCloud with 7934 points., False],
#  203: [PointCloud with 3652 points., False],
#  204: [PointCloud with 11245 points., False],
#  205: [PointCloud with 2102 points., False],
#  206: [PointCloud with 9652 points., False],
#  207: [PointCloud with 9516 points., False],
#  208: [PointCloud with 2814 points., False],
#  209: [PointCloud with 9979 points., False],
#  210: [PointCloud with 8262 points., False],
#  211: [PointCloud with 14150 points., False],
#  212: [PointCloud with 2317 points., False],
#  213: [PointCloud with 695 points., False],
#  214: [PointCloud with 1506 points., False],
#  215: [PointCloud with 4330 points., False],
#  216: [PointCloud with 9301 points., False],
#  217: [PointCloud with 2675 points., False],
#  218: [PointCloud with 983 points., False],
#  219: [PointCloud with 4966 points., False],
#  220: [PointCloud with 778 points., False],
#  221: [PointCloud with 402 points., False],
#  222: [PointCloud with 5192 points., False],
#  223: [PointCloud with 6897 points., False],
#  224: [PointCloud with 574 points., False],
#  225: [PointCloud with 652 points., False],
#  226: [PointCloud with 589 points., False],
#  227: [PointCloud with 5943 points., False],
#  228: [PointCloud with 3419 points., False],
#  229: [PointCloud with 6796 points., False],
#  230: [PointCloud with 1980 points., False],
#  231: [PointCloud with 69 points., False],
#  232: [PointCloud with 2179 points., False],
#  233: [PointCloud with 6983 points., False],
#  234: [PointCloud with 11117 points., False],
#  235: [PointCloud with 5858 points., False],
#  236: [PointCloud with 926 points., False],
#  237: [PointCloud with 13818 points., False],
#  238: [PointCloud with 489 points., False],
#  239: [PointCloud with 7022 points., False],
#  240: [PointCloud with 2307 points., False],
#  241: [PointCloud with 7426 points., False],
#  242: [PointCloud with 4860 points., False],
#  243: [PointCloud with 1657 points., False],
#  244: [PointCloud with 13 points., False],
#  245: [PointCloud with 2601 points., False],
#  246: [PointCloud with 8752 points., False],
#  247: [PointCloud with 3705 points., False],
#  248: [PointCloud with 5681 points., False],
#  249: [PointCloud with 2649 points., False],
#  250: [PointCloud with 12766 points., False],
#  251: [PointCloud with 924 points., False],
#  252: [PointCloud with 5520 points., False],
#  253: [PointCloud with 3138 points., False],
#  254: [PointCloud with 3906 points., False],
#  255: [PointCloud with 3869 points., False],
#  256: [PointCloud with 4256 points., False],
#  257: [PointCloud with 16120 points., False],
#  258: [PointCloud with 12 points., False],
#  259: [PointCloud with 10517 points., False],
#  260: [PointCloud with 1802 points., False],
#  261: [PointCloud with 1005 points., False],
#  262: [PointCloud with 1371 points., False],
#  263: [PointCloud with 4127 points., False],
#  264: [PointCloud with 2955 points., False],
#  265: [PointCloud with 7178 points., False],
#  266: [PointCloud with 8054 points., False],
#  267: [PointCloud with 7829 points., False],
#  268: [PointCloud with 1413 points., False],
#  269: [PointCloud with 1403 points., False],
#  270: [PointCloud with 3594 points., False],
#  271: [PointCloud with 5823 points., False],
#  272: [PointCloud with 1906 points., False],
#  273: [PointCloud with 10156 points., False],
#  274: [PointCloud with 6929 points., False],
#  275: [PointCloud with 1420 points., False],
#  276: [PointCloud with 1303 points., False],
#  277: [PointCloud with 972 points., False],
#  278: [PointCloud with 938 points., False],
#  279: [PointCloud with 1310 points., False],
#  280: [PointCloud with 9812 points., False],
#  281: [PointCloud with 485 points., False],
#  282: [PointCloud with 8017 points., False],
#  283: [PointCloud with 782 points., False],
#  284: [PointCloud with 956 points., False],
#  285: [PointCloud with 1842 points., False],
#  286: [PointCloud with 2550 points., False],
#  287: [PointCloud with 7776 points., False],
#  288: [PointCloud with 5982 points., False],
#  289: [PointCloud with 19952 points., False],
#  290: [PointCloud with 3048 points., False],
#  291: [PointCloud with 3355 points., False],
#  292: [PointCloud with 5022 points., False],
#  293: [PointCloud with 1644 points., False],
#  294: [PointCloud with 19188 points., False],
#  295: [PointCloud with 10412 points., False],
#  296: [PointCloud with 6454 points., False],
#  297: [PointCloud with 701 points., False],
#  298: [PointCloud with 1463 points., False],
#  299: [PointCloud with 4977 points., False],
#  300: [PointCloud with 6123 points., False],
#  301: [PointCloud with 282 points., False],
#  302: [PointCloud with 465 points., False],
#  303: [PointCloud with 4569 points., False],
#  304: [PointCloud with 5951 points., False],
#  305: [PointCloud with 734 points., False],
#  306: [PointCloud with 12168 points., False],
#  307: [PointCloud with 5317 points., False],
#  308: [PointCloud with 6092 points., False],
#  309: [PointCloud with 3752 points., False],
#  310: [PointCloud with 3807 points., False],
#  311: [PointCloud with 3601 points., False],
#  312: [PointCloud with 10802 points., False],
#  313: [PointCloud with 8801 points., False],
#  314: [PointCloud with 8070 points., False],
#  315: [PointCloud with 9084 points., False],
#  316: [PointCloud with 22505 points., False],
#  317: [PointCloud with 8879 points., False],
#  318: [PointCloud with 681 points., False],
#  319: [PointCloud with 8727 points., False],
#  320: [PointCloud with 15739 points., False],
#  321: [PointCloud with 7934 points., False],
#  322: [PointCloud with 3652 points., False],
#  323: [PointCloud with 11245 points., False],
#  324: [PointCloud with 2102 points., False],
#  325: [PointCloud with 9652 points., False],
#  326: [PointCloud with 9516 points., False],
#  327: [PointCloud with 2814 points., False],
#  328: [PointCloud with 9979 points., False],
#  329: [PointCloud with 8262 points., False],
#  330: [PointCloud with 14150 points., False],
#  331: [PointCloud with 2317 points., False],
#  332: [PointCloud with 695 points., False],
#  333: [PointCloud with 1506 points., False],
#  334: [PointCloud with 4330 points., False],
#  335: [PointCloud with 9301 points., False],
#  336: [PointCloud with 2675 points., False],
#  337: [PointCloud with 983 points., False],
#  338: [PointCloud with 4966 points., False],
#  339: [PointCloud with 778 points., False],
#  340: [PointCloud with 402 points., False],
#  341: [PointCloud with 5192 points., False],
#  342: [PointCloud with 6897 points., False],
#  343: [PointCloud with 574 points., False],
#  344: [PointCloud with 652 points., False],
#  345: [PointCloud with 589 points., False],
#  346: [PointCloud with 5943 points., False],
#  347: [PointCloud with 3419 points., False],
#  348: [PointCloud with 6796 points., False],
#  349: [PointCloud with 1980 points., False],
#  350: [PointCloud with 69 points., False],
#  351: [PointCloud with 2179 points., False],
#  352: [PointCloud with 6983 points., False],
#  353: [PointCloud with 11117 points., False],
#  354: [PointCloud with 5858 points., False],
#  355: [PointCloud with 926 points., False],
#  356: [PointCloud with 13818 points., False]}

# %% [markdown]
# ## 2.3. Merge of the semantic information in a single point cloud
#
# Now that we have the DTM and each synthetic tree simulated, we are going to merge them in a single forest point cloud.

# %%
import copy

ARBOLES = []
NUBES_ARTIFICIALES = {}
#superficie = SUPERFICIES[0]
superficie = pcd_DTM
ARBOLES.append([])

Numero_arboles_por_nube = 100

puntos_superficie = np.array(superficie.points)


SEGMENTOS_ARTIFICIALES_aux = copy.deepcopy(SEGMENTOS_ARTIFICIALES)





contador = 0
cuntudur = 0
for j in range(Numero_arboles_por_nube):

    # Si ya hemos terminado de poner todos los árboles que teníamos
    # creados volvemos a empezar:
    if cuntudur == len(SEGMENTOS_ARTIFICIALES_aux):
        # print(SEGMENTOS_ARTIFICIALES[0])
        # SEGMENTOS_ARTIFICIALES_aux.clear()
        SEGMENTOS_ARTIFICIALES_aux = copy.deepcopy(SEGMENTOS_ARTIFICIALES)
        # print(SEGMENTOS_ARTIFICIALES[0])
        cuntudur = 0

    posible_ubicacion = puntos_superficie[np.random.choice(len(puntos_superficie))]

    indice = np.random.choice(len(SEGMENTOS_ARTIFICIALES_aux))
    # Cojo un árbol al azar:
    arbol = SEGMENTOS_ARTIFICIALES_aux[indice]
    # arbol = SEGMENTOS_ARTIFICIALES[10] # Ejemplo

    while arbol[1] == True:
        indice = np.random.choice(len(SEGMENTOS_ARTIFICIALES_aux))
        arbol = SEGMENTOS_ARTIFICIALES_aux[indice]
    if arbol[1] == False:
        cuntudur += 1

    arbol = arbol[0]
    # Le ponemosla etiqueta True porque ya ha sido seleccionado:
    SEGMENTOS_ARTIFICIALES_aux[indice][1] = True
    SEGMENTOS_ARTIFICIALES[indice][1] = False
    # if cuntudur == 1:
    #     print(SEGMENTOS_ARTIFICIALES_aux[indice][1])
    #     print(SEGMENTOS_ARTIFICIALES[indice][1])
    arbol.translate((posible_ubicacion),relative=False)

    puntos_arbol = np.array(arbol.points)
    minima_altura = puntos_arbol.take(2,1).min()

    color_arbol = np.array(arbol.colors)

    desfase_vertical = posible_ubicacion-minima_altura

    puntos_arbol[:, 2] = puntos_arbol.take(2,1) + desfase_vertical[2]
    arbol = o3d.geometry.PointCloud()
    arbol.points = o3d.utility.Vector3dVector(puntos_arbol)
    arbol.colors = o3d.utility.Vector3dVector(color_arbol)


    ARBOLES[-1].append(arbol)

    if contador == 0:

        nube_artificial = arbol+superficie
        contador += 1

    else:
        nube_artificial += arbol


# Metemos todos los árboles que coleccionamos en un sólo elemento:
arbol = o3d.geometry.PointCloud()

for arbol_i in ARBOLES[-1]:
    arbol += arbol_i

# Cambiamos tooodos los elementos por uno sólo que serán todos los ár-
# boles:
ARBOLES = arbol
NUBES_ARTIFICIALES = nube_artificial


# VISUALIZATION TEST ----------------------------------------------------------
o3d.visualization.draw_geometries([NUBES_ARTIFICIALES])
#------------------------------------------------------------------------------

# %% [markdown]
# Finally, the synthetic forest point cloud should be something similar to this:
#
# ![alternative text](images/synthetic_forest.png)

# %% [markdown]
# Also, you can try to change some parameters like the spatial dimensions, number of trees, shaders, etc...
#
# ![alternative text](images/synthetic_forest_2.png)

# %% [markdown]
# Before jumping to the last part of the course, we will see how to save this information as a "readable" file for the DL model that was chosen: PointNet++.

# %%
os.chdir(ruta_proyecto_workshop+'/data/synthetic_point_clouds')
try:
    os.mkdir('my_first_cloud')
except FileExistsError:
    print('The folder already exists')
os.chdir('my_first_cloud')
# Out:
# The folder already exists

# %%
puntos_arboles = np.array(ARBOLES.points)
with open("arboles.npy", 'wb') as f:    
    np.save(f, puntos_arboles)
with open("DTM.npy", 'wb') as f:    
    np.save(f, puntos_superficie)
